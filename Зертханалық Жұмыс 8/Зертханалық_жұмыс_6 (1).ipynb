# %% [markdown]
# Осы аптадағы тәжірибелік зертханада сіз бір конфигурацияны қолданып көресіз және бұл желілердің көптеген түрлерінің тіркесімі: деректер терезелері конвульсиядан өтеді, одан кейін жинақталған LSTM, содан кейін жинақталған тығыз қабаттар.

# %% [markdown]
# ## Қажетті модульдерді импорттаңыз

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
def plot_series(x, y, format="-", start=0, end=None,
                title=None, xlabel=None, ylabel=None, legend=None ):
    """
    Уақыттық қатар деректерін визуалдау

    Параметрлер:
      x (бүтін сандар массиві) - x осіне арналған мәндерді қамтиды
      y (бүтін сандар массиві немесе массивтердің жұбы) - y осіне арналған мәндерді қамтиды
      format (жол) - график сызығының стилі
      start (бүтін сан) - графикте көрсетілетін бірінші уақыт қадамы
      end (бүтін сан) - графикте көрсетілетін соңғы уақыт қадамы
      title (жол) - графиктің тақырыбы
      xlabel (жол) - x осінің атауы
      ylabel (жол) - y осінің атауы
      legend (жолдар тізімі) - графиктің легендасы
    """

    # График фигурасының өлшемдерін орнату
    plt.figure(figsize=(10, 6))

    # Екіден көп қатарды графиктеу қажет пе екенін тексеру
    if type(y) is tuple:

      # y элементтері бойынша цикл жасау
      for y_curr in y:

        # x және ағымдағы y мәндерін графиктеу
        plt.plot(x[start:end], y_curr[start:end], format)

    else:
      # x және y мәндерін графиктеу
      plt.plot(x[start:end], y[start:end], format)

    # x осінің атауын белгілеу
    plt.xlabel(xlabel)

    # y осінің атауын белгілеу
    plt.ylabel(ylabel)

    # Легенданы орнату
    if legend:
      plt.legend(legend)

    # Тақырыпты орнату
    plt.title(title)

    # Графиктің үстіне тор сызбасын қосу
    plt.grid(True)

    # Экранда графикті көрсету
    plt.show()

# %% [markdown]
# ## Деректер жинағын жүктеп алыңыз және алдын ала қараңыз

# %%
# !wget -nc https://www.kaggle.com/datasets/samfaraday/daily-minimum-temperatures-in-me
# Out:
# --2025-03-29 07:44:53--  https://www.kaggle.com/datasets/samfaraday/daily-minimum-temperatures-in-me
# Resolving www.kaggle.com (www.kaggle.com)... 35.244.233.98
# Connecting to www.kaggle.com (www.kaggle.com)|35.244.233.98|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘daily-minimum-temperatures-in-me’
#
# daily-minimum-tempe     [ <=>                ]   9.59K  --.-KB/s    in 0.001s
#
# 2025-03-29 07:44:54 (16.9 MB/s) - ‘daily-minimum-temperatures-in-me’ saved [9818]

# %%
# Тізімдерді инициализациялау
time_step = []
sunspots = []

# CSV файлын ашу
with open('daily-minimum-temperatures-in-me.csv') as csvfile:

  # Оқырманды инициализациялау
  reader = csv.reader(csvfile, delimiter=',')

  # Бірінші жолды өткізіп жіберу
  next(reader)

  # Әр жолдан уақыт қадамы мен күн нүктелерінің санын тізімге қосу
  for row in reader:
    time_step.append(int(row[0]))
    sunspots.append(float(row[2]))

# Тізімдерді numpy массивтеріне ауыстыру
time = np.array(time_step)
series = np.array(sunspots)

# Деректерді алдын ала қарау
plot_series(time, series, xlabel='Ай', ylabel='Ай сайынғы орташа күн нүктелерінің саны')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-518fa8097129> in <cell line: 0>()
#      14   # Әр жолдан уақыт қадамы мен күн нүктелерінің санын тізімге қосу
#      15   for row in reader:
# ---> 16     time_step.append(int(row[0]))
#      17     sunspots.append(float(row[2]))
#      18
#
# ValueError: invalid literal for int() with base 10: '1/1/1981'

# %%
import pandas as pd

df = pd.read_csv("daily-minimum-temperatures-in-me.csv")
df
# Out:
#             Date Daily minimum temperatures
# 0       1/1/1981                       20.7
# 1       1/2/1981                       17.9
# 2       1/3/1981                       18.8
# 3       1/4/1981                       14.6
# 4       1/5/1981                       15.8
# ...          ...                        ...
# 3645  12/27/1990                         14
# 3646  12/28/1990                       13.6
# 3647  12/29/1990                       13.5
# 3648  12/30/1990                       15.7
# 3649  12/31/1990                         13
#
# [3650 rows x 2 columns]

# %%
print(f"Уақыт қадамдары саны: {len(time_step)}")
print(f"Күн нүктелері саны: {len(sunspots)}")
# Out:
# Уақыт қадамдары саны: 0
# Күн нүктелері саны: 0

# %%
with open("daily-minimum-temperatures-in-me.csv", encoding="utf-8") as csvfile:
    reader = csv.reader(csvfile)
    for i, row in enumerate(reader):
        print(row)
        if i == 5:  # Тек 5 жол шығару
            break
# Out:
# ['Date', 'Daily minimum temperatures']
# ['1/1/1981', '20.7']
# ['1/2/1981', '17.9']
# ['1/3/1981', '18.8']
# ['1/4/1981', '14.6']
# ['1/5/1981', '15.8']

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

# Тізімдерді инициализациялау
time_step = []
temperatures = []

# CSV файлын ашу
with open("daily-minimum-temperatures-in-me.csv", encoding="utf-8") as csvfile:
    reader = csv.reader(csvfile)
    next(reader)  # Бірінші жолды өткізіп жіберу (баған атаулары)

    for row in reader:
        try:
            date = datetime.strptime(row[0].strip(), "%m/%d/%Y")  # Датаны дұрыс оқу
            temp_str = row[1].strip()  # Артық бос орындарды алып тастау

            # Егер мән "?" немесе бос болса, оны өткізіп жібереміз
            if temp_str in ["", "?", "NaN"]:
                continue

            temperature = float(temp_str)  # Температура мәнін алу
            time_step.append(date)
            temperatures.append(temperature)

        except ValueError as e:
            print(f"Қате жол: {row} ({e})")  # Қате жолдарды шығарып көрсету

# Деректерді numpy массивтеріне айналдыру
time = np.array(time_step)
series = np.array(temperatures)

# Деректерді визуализациялау
plt.figure(figsize=(10, 5))
plt.plot(time, series, label="Күнделікті минималды температура", color="blue")
plt.xlabel("Жыл")
plt.ylabel("Температура (°C)")
plt.title("Күнделікті минималды температуралар")
plt.legend()
plt.grid()
plt.show()
# Out:
# Қате жол: ['7/20/1982', '?0.2'] (could not convert string to float: '?0.2')
# Қате жол: ['7/21/1982', '?0.8'] (could not convert string to float: '?0.8')
# Қате жол: ['7/14/1984', '?0.1'] (could not convert string to float: '?0.1')

# %% [markdown]
# ## Деректер жиынын бөліңіз

# %%
# Define the split time
split_time = 3000

# Get the train set
time_train = time[:split_time]
x_train = series[:split_time]

# Get the validation set
time_valid = time[split_time:]
x_valid = series[split_time:]

# %% [markdown]
# ## Мүмкіндіктер мен белгілерді дайындаңыз

# %%
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
    """Деректер жиынтығының терезелерін құрады

    Параметрлер:
      series (float сандар массиві) - уақыттық қатардың мәндерін қамтиды
      window_size (бүтін сан) - ерекшелікке енгізілетін уақыт қадамдарының саны
      batch_size (бүтін сан) - пакет көлемі
      shuffle_buffer (бүтін сан) - араластыру әдісі үшін қолданылатын буфер көлемі

    Қайтарады:
      dataset (TF Dataset) - уақыттық терезелерді қамтитын TF деректер жиынтығы
    """

    # RNN қабаттарының ерекшелік өлшемі үшін қосымша ось қосу
    series = tf.expand_dims(series, axis=-1)

    # Серия мәндерінен TF деректер жиынтығын жасау
    dataset = tf.data.Dataset.from_tensor_slices(series)

    # Деректерді терезеге бөлу, тек көрсетілген өлшемдегі терезелерді таңдау
    dataset = dataset.window(window_size + 1, shift=1, drop_remainder=True)

    # Терезелерді бір пакетке біріктіру арқылы тегістеу
    dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))

    # Ерекшеліктер мен белгілерді қамтитын кортеждерді жасау
    dataset = dataset.map(lambda window: (window[:-1], window[-1]))

    # Терезелерді араластыру
    dataset = dataset.shuffle(shuffle_buffer)

    # Терезелердің пакеттерін жасау
    dataset = dataset.batch(batch_size)

    # Оқыту үшін деректер жиынтығын оңтайландыру
    dataset = dataset.cache().prefetch(1)

    return dataset

# %% [markdown]
# егер сіздің нәтижелеріңіз жақсы болмаса, мұнда параметрлерді өзгертуге және модельдің жақсырақ үйренетінін көруге болады.

# %%
# Параметрлер
window_size = 30
batch_size = 32
shuffle_buffer_size = 1000

# Деректер жиынының терезелерін жасаңыз
train_set = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer_size)

# %% [markdown]
# ## Үлгіні құрастыру

# %%
model = tf.keras.models.Sequential([
    tf.keras.Input(shape=(window_size,1)),
    tf.keras.layers.Conv1D(filters=64, kernel_size=3,
                      strides=1,
                      activation="relu",
                      padding='causal'),
    tf.keras.layers.LSTM(64, return_sequences=True),
    tf.keras.layers.LSTM(64),
    tf.keras.layers.Dense(30, activation="relu"),
    tf.keras.layers.Dense(10, activation="relu"),
    tf.keras.layers.Dense(1),
    tf.keras.layers.Lambda(lambda x: x * 400)
])

# Үлгінің қысқаша мазмұнын басып шығарыңыз
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                      │ (None, 30, 64)              │             256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 30, 64)              │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 64)                  │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 30)                  │           1,950 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │             310 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              11 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lambda (Lambda)                      │ (None, 1)                   │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 68,575 (267.87 KB)
#  Trainable params: 68,575 (267.87 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Оқу жылдамдығын реттеңіз
#
# оңтайлы оқу жылдамдығын таңдағыңыз келеді.

# %%
# Бастапқы салмақтарды алыңыз
init_weights = model.get_weights()

# %%
# Оқу жылдамдығын реттегішті орнату
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-8 * 10**(epoch / 20))

# Оптимизаторды инициализациялау
optimizer = tf.keras.optimizers.SGD(momentum=0.9)

# Оқыту параметрлерін орнату
model.compile(loss=tf.keras.losses.Huber(), optimizer=optimizer)

# Модельді оқыту
history = model.fit(train_set, epochs=100, callbacks=[lr_schedule])
# Out:
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 128.3322 - learning_rate: 1.0000e-08
# Epoch 2/100
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:151: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 75.6999 - learning_rate: 1.1220e-08
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 48.0621 - learning_rate: 1.2589e-08
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 23.4788 - learning_rate: 1.4125e-08
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 3.4941 - learning_rate: 1.5849e-08
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.5082 - learning_rate: 1.7783e-08
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.3980 - learning_rate: 1.9953e-08
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.3075 - learning_rate: 2.2387e-08
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.2278 - learning_rate: 2.5119e-08
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.1599 - learning_rate: 2.8184e-08
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.1051 - learning_rate: 3.1623e-08
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.0571 - learning_rate: 3.5481e-08
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.0158 - learning_rate: 3.9811e-08
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.9807 - learning_rate: 4.4668e-08
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.9529 - learning_rate: 5.0119e-08
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.9286 - learning_rate: 5.6234e-08
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.9071 - learning_rate: 6.3096e-08
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.8870 - learning_rate: 7.0795e-08
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.8712 - learning_rate: 7.9433e-08
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.8583 - learning_rate: 8.9125e-08
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.8462 - learning_rate: 1.0000e-07
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.8348 - learning_rate: 1.1220e-07
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.8256 - learning_rate: 1.2589e-07
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.8173 - learning_rate: 1.4125e-07
# Epoch 25/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.8090 - learning_rate: 1.5849e-07
# Epoch 26/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.8016 - learning_rate: 1.7783e-07
# Epoch 27/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.7953 - learning_rate: 1.9953e-07
# Epoch 28/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.7901 - learning_rate: 2.2387e-07
# Epoch 29/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.7861 - learning_rate: 2.5119e-07
# Epoch 30/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.7826 - learning_rate: 2.8184e-07
# Epoch 31/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.7789 - learning_rate: 3.1623e-07
# Epoch 32/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.7736 - learning_rate: 3.5481e-07
# Epoch 33/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.7666 - learning_rate: 3.9811e-07
# Epoch 34/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.7601 - learning_rate: 4.4668e-07
# Epoch 35/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.7483 - learning_rate: 5.0119e-07
# Epoch 36/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.7356 - learning_rate: 5.6234e-07
# Epoch 37/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.7277 - learning_rate: 6.3096e-07
# Epoch 38/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.7114 - learning_rate: 7.0795e-07
# Epoch 39/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.6880 - learning_rate: 7.9433e-07
# Epoch 40/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.6783 - learning_rate: 8.9125e-07
# Epoch 41/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.6780 - learning_rate: 1.0000e-06
# Epoch 42/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.6937 - learning_rate: 1.1220e-06
# Epoch 43/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.7146 - learning_rate: 1.2589e-06
# Epoch 44/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.7205 - learning_rate: 1.4125e-06
# Epoch 45/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.7439 - learning_rate: 1.5849e-06
# Epoch 46/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.7606 - learning_rate: 1.7783e-06
# Epoch 47/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.6978 - learning_rate: 1.9953e-06
# Epoch 48/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.7198 - learning_rate: 2.2387e-06
# Epoch 49/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.7666 - learning_rate: 2.5119e-06
# Epoch 50/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.8113 - learning_rate: 2.8184e-06
# Epoch 51/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.7977 - learning_rate: 3.1623e-06
# Epoch 52/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.1407 - learning_rate: 3.5481e-06
# Epoch 53/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.3332 - learning_rate: 3.9811e-06
# Epoch 54/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.2880 - learning_rate: 4.4668e-06
# Epoch 55/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.3297 - learning_rate: 5.0119e-06
# Epoch 56/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.1286 - learning_rate: 5.6234e-06
# Epoch 57/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.0512 - learning_rate: 6.3096e-06
# Epoch 58/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.8139 - learning_rate: 7.0795e-06
# Epoch 59/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.8239 - learning_rate: 7.9433e-06
# Epoch 60/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.8402 - learning_rate: 8.9125e-06
# Epoch 61/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.3633 - learning_rate: 1.0000e-05
# Epoch 62/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.4295 - learning_rate: 1.1220e-05
# Epoch 63/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.9997 - learning_rate: 1.2589e-05
# Epoch 64/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.4235 - learning_rate: 1.4125e-05
# Epoch 65/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.0674 - learning_rate: 1.5849e-05
# Epoch 66/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.3957 - learning_rate: 1.7783e-05
# Epoch 67/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.0263 - learning_rate: 1.9953e-05
# Epoch 68/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.8584 - learning_rate: 2.2387e-05
# Epoch 69/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.8534 - learning_rate: 2.5119e-05
# Epoch 70/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.1325 - learning_rate: 2.8184e-05
# Epoch 71/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.3845 - learning_rate: 3.1623e-05
# Epoch 72/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.4831 - learning_rate: 3.5481e-05
# Epoch 73/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.5629 - learning_rate: 3.9811e-05
# Epoch 74/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.4147 - learning_rate: 4.4668e-05
# Epoch 75/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.2995 - learning_rate: 5.0119e-05
# Epoch 76/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.6694 - learning_rate: 5.6234e-05
# Epoch 77/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.6191 - learning_rate: 6.3096e-05
# Epoch 78/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.8566 - learning_rate: 7.0795e-05
# Epoch 79/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 7.9303 - learning_rate: 7.9433e-05
# Epoch 80/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 8.7541 - learning_rate: 8.9125e-05
# Epoch 81/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 5.3095 - learning_rate: 1.0000e-04
# Epoch 82/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 8.2529 - learning_rate: 1.1220e-04
# Epoch 83/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 10.0090 - learning_rate: 1.2589e-04
# Epoch 84/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 8.7914 - learning_rate: 1.4125e-04
# Epoch 85/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 14.1725 - learning_rate: 1.5849e-04
# Epoch 86/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 14.3981 - learning_rate: 1.7783e-04
# Epoch 87/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 29.9883 - learning_rate: 1.9953e-04
# Epoch 88/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 34.2170 - learning_rate: 2.2387e-04
# Epoch 89/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 29.3558 - learning_rate: 2.5119e-04
# Epoch 90/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 40.7834 - learning_rate: 2.8184e-04
# Epoch 91/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 33.7516 - learning_rate: 3.1623e-04
# Epoch 92/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 49.6472 - learning_rate: 3.5481e-04
# Epoch 93/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 31.7001 - learning_rate: 3.9811e-04
# Epoch 94/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 51.7045 - learning_rate: 4.4668e-04
# Epoch 95/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 41.4055 - learning_rate: 5.0119e-04
# Epoch 96/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 65.1359 - learning_rate: 5.6234e-04
# Epoch 97/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 74.7687 - learning_rate: 6.3096e-04
# Epoch 98/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 97.6688 - learning_rate: 7.0795e-04
# Epoch 99/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 177.9286 - learning_rate: 7.9433e-04
# Epoch 100/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 107.3446 - learning_rate: 8.9125e-04

# %%
# Оқу жылдамдығының массивін анықтау
lrs = 1e-8 * (10 ** (np.arange(100) / 20))

# Фигураның өлшемін орнату
plt.figure(figsize=(10, 6))

# Торды орнату
plt.grid(True)

# Логарифмдік масштабта жоғалту мәнін графиктеу
plt.semilogx(lrs, history.history["loss"])

# Тик белгішелерінің өлшемін ұлғайту
plt.tick_params('both', length=10, width=1, which='both')

# Графиктің шекараларын орнату
plt.axis([1e-8, 1e-3, 0, 100])
# Out:
# (np.float64(1e-08), np.float64(0.001), np.float64(0.0), np.float64(100.0))

# %% [markdown]
# ## Үлгіні жаттықтыру
#
# Енді үлгіні қалпына келтіруге және үйретуге болады. Ол төмендегі ұяшықта 100 дәуірге орнатылған, бірақ қаласаңыз, оны көбейтуге болады.

# %%
# Keras жасаған күйді қалпына келтіру
tf.keras.backend.clear_session()

# Салмақтарды қалпына келтіру
model.set_weights(init_weights)

# %%
# Оқу жылдамдығын орнату
learning_rate = 8e-7

# Оптимизаторды орнату
optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=0.9)

# Оқыту параметрлерін орнату
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])

# %%
# Модельді оқыту
history = model.fit(train_set, epochs=100)
# Out:
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 37.8341 - mae: 38.3236
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.9415 - mae: 2.3972
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.8945 - mae: 2.3497
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.8543 - mae: 2.3083
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.8015 - mae: 2.2542
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.7807 - mae: 2.2344
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.7666 - mae: 2.2185
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.7466 - mae: 2.1972
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.7200 - mae: 2.1688
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.7034 - mae: 2.1508
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.6912 - mae: 2.1381
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.6813 - mae: 2.1273
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.6746 - mae: 2.1205
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.6686 - mae: 2.1148
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.6633 - mae: 2.1094
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.6583 - mae: 2.1043
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.6532 - mae: 2.0991
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.6484 - mae: 2.0944
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.6443 - mae: 2.0903
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.6400 - mae: 2.0861
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6365 - mae: 2.0825
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.6322 - mae: 2.0782
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.6285 - mae: 2.0743
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.6247 - mae: 2.0706
# Epoch 25/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.6209 - mae: 2.0667
# Epoch 26/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.6176 - mae: 2.0633
# Epoch 27/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.6149 - mae: 2.0605
# Epoch 28/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.6115 - mae: 2.0571
# Epoch 29/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.6084 - mae: 2.0540
# Epoch 30/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.6054 - mae: 2.0509
# Epoch 31/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.6025 - mae: 2.0480
# Epoch 32/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.6001 - mae: 2.0454
# Epoch 33/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5975 - mae: 2.0428
# Epoch 34/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5947 - mae: 2.0401
# Epoch 35/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5922 - mae: 2.0375
# Epoch 36/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5896 - mae: 2.0350
# Epoch 37/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5874 - mae: 2.0328
# Epoch 38/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5852 - mae: 2.0306
# Epoch 39/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.5831 - mae: 2.0285
# Epoch 40/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5808 - mae: 2.0263
# Epoch 41/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5789 - mae: 2.0243
# Epoch 42/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5770 - mae: 2.0223
# Epoch 43/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5752 - mae: 2.0206
# Epoch 44/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5735 - mae: 2.0189
# Epoch 45/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5718 - mae: 2.0172
# Epoch 46/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5702 - mae: 2.0156
# Epoch 47/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5686 - mae: 2.0142
# Epoch 48/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5670 - mae: 2.0125
# Epoch 49/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5655 - mae: 2.0111
# Epoch 50/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5640 - mae: 2.0096
# Epoch 51/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5627 - mae: 2.0083
# Epoch 52/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5614 - mae: 2.0069
# Epoch 53/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5599 - mae: 2.0054
# Epoch 54/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5588 - mae: 2.0043
# Epoch 55/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5576 - mae: 2.0031
# Epoch 56/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5564 - mae: 2.0019
# Epoch 57/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.5554 - mae: 2.0009
# Epoch 58/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.5544 - mae: 1.9998
# Epoch 59/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5533 - mae: 1.9988
# Epoch 60/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5524 - mae: 1.9978
# Epoch 61/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5513 - mae: 1.9967
# Epoch 62/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5503 - mae: 1.9955
# Epoch 63/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5495 - mae: 1.9947
# Epoch 64/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5487 - mae: 1.9939
# Epoch 65/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5478 - mae: 1.9929
# Epoch 66/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5469 - mae: 1.9921
# Epoch 67/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5463 - mae: 1.9916
# Epoch 68/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5453 - mae: 1.9905
# Epoch 69/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5447 - mae: 1.9898
# Epoch 70/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5442 - mae: 1.9893
# Epoch 71/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5435 - mae: 1.9886
# Epoch 72/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5427 - mae: 1.9877
# Epoch 73/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5425 - mae: 1.9876
# Epoch 74/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5415 - mae: 1.9866
# Epoch 75/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.5412 - mae: 1.9862
# Epoch 76/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5406 - mae: 1.9856
# Epoch 77/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5399 - mae: 1.9849
# Epoch 78/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5395 - mae: 1.9844
# Epoch 79/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5389 - mae: 1.9838
# Epoch 80/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5384 - mae: 1.9833
# Epoch 81/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5380 - mae: 1.9829
# Epoch 82/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5373 - mae: 1.9822
# Epoch 83/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5367 - mae: 1.9816
# Epoch 84/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5364 - mae: 1.9812
# Epoch 85/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5357 - mae: 1.9806
# Epoch 86/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5355 - mae: 1.9804
# Epoch 87/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5348 - mae: 1.9796
# Epoch 88/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5346 - mae: 1.9795
# Epoch 89/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5339 - mae: 1.9787
# Epoch 90/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5337 - mae: 1.9785
# Epoch 91/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5330 - mae: 1.9778
# Epoch 92/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5330 - mae: 1.9778
# Epoch 93/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.5325 - mae: 1.9772
# Epoch 94/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.5321 - mae: 1.9768
# Epoch 95/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5314 - mae: 1.9761
# Epoch 96/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5310 - mae: 1.9757
# Epoch 97/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5310 - mae: 1.9756
# Epoch 98/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5305 - mae: 1.9752
# Epoch 99/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5300 - mae: 1.9746
# Epoch 100/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5298 - mae: 1.9743

# %% [markdown]
# Сіз жаттығуды визуализациялай аласыз және жоғалту мен MAE әлі де төмендейтінін көре аласыз.

# %%
import matplotlib.pyplot as plt

# Тарих жазбасынан mae және loss мәндерін алу
mae = history.history['mae']
loss = history.history['loss']

# Эпохалардың санын алу
epochs = list(range(len(loss)))  # `range` → `list`

# MAE және Loss графигін салу
plt.figure(figsize=(10, 5))
plt.plot(epochs, mae, label="MAE", color="blue")
plt.plot(epochs, loss, label="Loss", color="red")
plt.xlabel("Эпоха")
plt.ylabel("Loss")
plt.title("MAE және Loss")
plt.legend()
plt.grid()
plt.show()

# Тек соңғы 80% эпохаларды графиктеу
zoom_split = int(len(epochs) * 0.2)
epochs_zoom = epochs[zoom_split:]
mae_zoom = mae[zoom_split:]
loss_zoom = loss[zoom_split:]

# Үлкейтілген MAE және Loss графигін салу
plt.figure(figsize=(10, 5))
plt.plot(epochs_zoom, mae_zoom, label="MAE", color="blue")
plt.plot(epochs_zoom, loss_zoom, label="Loss", color="red")
plt.xlabel("Эпоха")
plt.ylabel("Loss")
plt.title("MAE және Loss (соңғы 80%)")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Модель болжауы
#
# Алдыңғыдай, валидациялық жиынтықтың уақыт диапазоны бойынша болжамдарды алып, метрикаларды есептей аласыз.

# %%
def model_forecast(model, series, window_size, batch_size):
    """Модельді қолданып, деректер терезелеріндегі болжамдарды генерациялайды

    Параметрлер:
      model (TF Keras Model) - деректер терезелерін қабылдайтын модель
      series (float сандар массиві) - уақыттық қатардың мәндерін қамтиды
      window_size (бүтін сан) - терезеге енгізілетін уақыт қадамдарының саны
      batch_size (бүтін сан) - пакет көлемі

    Қайтарады:
      forecast (numpy массиві) - болжамдарды қамтитын массив
    """

    # RNN қабаттарының ерекшелік өлшемі үшін қосымша ось қосу
    series = tf.expand_dims(series, axis=-1)

    # Серия мәндерінен TF деректер жиынтығын жасау
    dataset = tf.data.Dataset.from_tensor_slices(series)

    # Деректерді терезеге бөлу, тек көрсетілген өлшемдегі терезелерді таңдау
    dataset = dataset.window(window_size, shift=1, drop_remainder=True)

    # Терезелерді бір пакетке біріктіру арқылы тегістеу
    dataset = dataset.flat_map(lambda w: w.batch(window_size))

    # Терезелердің пакеттерін жасау және алдын ала жүктеу
    dataset = dataset.batch(batch_size).prefetch(1)

    # Барлық деректер жиынтығына болжам алу
    forecast = model.predict(dataset, verbose=0)

    return forecast

# %%
# Түпнұсқа қатарды қысқарту
forecast_series = series[split_time-window_size:-1]

# Болжамдарды генерациялау үшін көмекші функцияны қолдану
forecast = model_forecast(model, forecast_series, window_size, batch_size)

# Бірөлшемді осьті алып тастау
results = forecast.squeeze()

plot_series(time_valid, *[x_valid, results])

# %%
# Compute the MAE
print(tf.keras.metrics.mae(x_valid, results).numpy())
# Out:
# 1.7622287

# %% [markdown]
# ## Тапсырма
#
# Уақыт қатарларының деректер жинағын желіден табыңыз немесе оны өзіңіз талдай аласыз, берілген үлгіні пайдаланып уақыт қатарының болжамын жасаңыз
